# %%
import pandas as pd
import numpy as np
import os

# %%
base_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/segments_30s/features/male"

# %%
output_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/segments_30s/features/aggregated_male"

# %%
patient_list_file_dir = "/scratch/sshuvo13/scratch_run_dir_sajib/patient_list_wo_two/male_ids.txt"
with open(patient_list_file_dir, 'r', encoding='utf-8') as f:
    patient_list = [line.strip() for line in f.readlines()]

# %%
LPC_dir = os.path.join(base_dir, "LPC")
der_MFCC_avg_dir = os.path.join(base_dir, "der_MFCC_avg")
fraction_low_energy_dir = os.path.join(base_dir, "fraction_low_energy_windows")
PR800_dir =os.path.join(base_dir, "PR800")
Q_MFCC_avg_dir =os.path.join(base_dir, "Q_MFCC_avg")
RDF_dir = os.path.join(base_dir, "RDF")

# %%
# patient_id = "00001006-100507"

# %%
# extra strings written at the end of each patient's feature file
LPC_extra = "_LPC.csv"
der_MFCC_avg_extra = "_der_MFCC_avg.csv"
fraction_low_energy_extra = "_frac_low_en_features.csv"
# mel_spectrum_extra = ""
PR800_extra = "_PR800_features.csv"
Q_MFCC_avg_extra = "_Q_MFCC_avg.csv"
RDF_extra = "_RDF_features.csv"

# %%
def get_patient_features(patient_id: str, directory: str) -> pd.DataFrame:
    """
    Finds the CSV file containing the patient_id in its name within the given directory,
    reads it into a pandas DataFrame, and returns it.

    Args:
        patient_id (str): The unique patient identifier (e.g. "00000995-100507").
        directory (str): Path to the directory containing the CSV files.

    Returns:
        pd.DataFrame: The patient's feature data.

    Raises:
        FileNotFoundError: If no matching CSV file is found.
    """
    # Look for a CSV file containing the patient ID in its name
    matching_files = [
        f for f in os.listdir(directory)
        if f.endswith('.csv') and patient_id in f
    ]

    if not matching_files:
        raise FileNotFoundError(f"No CSV file found for patient ID: {patient_id}")

    # If multiple matches, take the first one (or modify to handle differently)
    file_path = os.path.join(directory, matching_files[0])

    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)

    return df

# %%
# feature_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/whole_dataset_features/male/RDF"
# patient_feature_df = get_patient_features(patient_id, feature_dir)

# %%
# patient_feature_df.head()

# %%
# def test_see_feature(patient_id, feature_name):
#     base_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/whole_dataset_features/male/"
#     feature_dir = os.path.join(base_dir, feature_name)
#     patient_feature_df = get_patient_features(patient_id, feature_dir)
#     display(patient_feature_df.head())

# %%
# feature_main_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/whole_dataset_features/male/"
# patient_id = 
# feature_name_list = [
#         name for name in os.listdir(feature_main_dir)
#         if os.path.isdir(os.path.join(feature_main_dir, name))
#     ]

# %%
feature_name_list = ['LPC',
 'Q_MFCC_avg',
 'PR800',
 'der_MFCC_avg',
 'fraction_low_energy_windows',
 'RDF']

# %%
# test_see_feature(patient_id, feature_name =  feature_name_list[0])

# %%
def aggregate_feature_single_patient(patient_id, feature_name_list, base_dir):

    aggregated_df_list = []
    # base_dir = "/scratch/sshuvo13/project_shared_folder_bspml_1/whole_dataset_features/male/"

    for feature_name in feature_name_list:
        feature_dir = os.path.join(base_dir, feature_name)
        patient_feature_df = get_patient_features(patient_id, feature_dir)
        label_separated = patient_feature_df['label']
        #dropping label and segment_index column
        patient_feature_df = patient_feature_df.drop(['label', 'segment_index'], axis=1)

        #adding feature name at the start of column name for two features (because it was not added previously)
        if(feature_name == 'fraction_low_energy_windows'):
            patient_feature_df = patient_feature_df.add_prefix("fraction_low_energy_")

        if(feature_name == 'LPC'):
            patient_feature_df = patient_feature_df.add_prefix("LPC_")

        aggregated_df_list.append(patient_feature_df)
        final_df = pd.concat(aggregated_df_list, axis=1)
        final_df['label'] = label_separated
        
    return final_df

# %%
# aggre_test =aggregate_feature(patient_id, feature_name_list)

# %%
# aggre_test.head()

# %%
# aggre_test.columns

# %%
# import matplotlib.pyplot as plt

# plt.hist(aggre_test['label'])

# %%
# aggre_test.to_csv("./outputs/features_33_nov21.csv", index= False )

# %%
for patient_id in patient_list:
    aggregated_single_patient_features_df = aggregate_feature_single_patient(patient_id, feature_name_list, base_dir)
    aggregated_single_patient_features_df.to_csv( os.path.join(output_dir,f"{patient_id}.csv"), index=False )
    print(f"Saved csv for {patient_id}")
# Out:
# Saved csv for 00001006-100507
# Saved csv for 00001008-100507
# Saved csv for 00001010-100507
# Saved csv for 00001018-100507
# Saved csv for 00001028-100507
# Saved csv for 00001041-100507
# Saved csv for 00001043-100507
# Saved csv for 00001086-100507
# Saved csv for 00001110-100507
# Saved csv for 00001120-100507
# Saved csv for 00001127-100507
# Saved csv for 00001131-100507
# Saved csv for 00001139-100507
# Saved csv for 00001143-100507
# Saved csv for 00001147-100507
# Saved csv for 00001182-100507
# Saved csv for 00001224-100507
# Saved csv for 00001245-100507
# Saved csv for 00001249-100507
# Saved csv for 00001256-100507
# Saved csv for 00001262-100507
# Saved csv for 00001274-100507
# Saved csv for 00001276-100507
# Saved csv for 00001295-100507
# Saved csv for 00001301-100507
# Saved csv for 00001318-100507
# Saved csv for 00001322-100507
# Saved csv for 00001324-100507
# Saved csv for 00001329-100507
# Saved csv for 00001331-100507
# Saved csv for 00001342-100507
# Saved csv for 00001355-100507
# Saved csv for 00001357-100507
# Saved csv for 00001369-100507
# Saved csv for 00001382-100507
# Saved csv for 00001390-100507
# Saved csv for 00001392-100507
# Saved csv for 00001396-100507
# Saved csv for 00001400-100507
# Saved csv for 00001408-100507
# Saved csv for 00001412-100507
# Saved csv for 00001444-100507
# Saved csv for 00001447-100507
# Saved csv for 00001449-100507
# Saved csv for 00001463-100507
# Saved csv for 00001488-100507
# Saved csv for 00001498-100507
# Saved csv for 00001508-100507
# Saved csv for 00001518-100507
# Saved csv for 00001521-100507
# Saved csv for 00001549-100507
# Saved csv for 00001558-100507
# Saved csv for 00001571-100507
# Saved csv for 00001575-100507
# Saved csv for 00001576-100507
# Saved csv for 00001579-100507
# Saved csv for 00001593-100507
# Saved csv for 00001597-100507
# Saved csv for 00001606-100507
# Saved csv for 00001616-100507
# Saved csv for 00001629-100507
# Saved csv for 00001636-100507
# Saved csv for 00001640-100507
# Saved csv for 00001649-100507
# Saved csv for 00001656-100507
# Saved csv for 00001658-100507
# Saved csv for 00001661-100507
# Saved csv for 00001667-100507
# Saved csv for 00001669-100507
# Saved csv for 00001673-100507
# Saved csv for 00001677-100507
# Saved csv for 00001681-100507
# Saved csv for 00001701-100507
