# %%
import os
import csv
import numpy as np
from pathlib import Path

# %%
# --- CONFIGURE THESE PATHS ---
source_dir = Path("/home/sshuvo13/BSPML_project_sbs_files/segmentation_30s/labels_again/fixed_30s_segment_details_of_each_label")   # directory containing CSV files
dest_dir   = Path("./fixed_30s_label_outputs/")      # directory to save npy files
# --------------------------------

# Create destination directory if it doesn't exist
dest_dir.mkdir(parents=True, exist_ok=True)

def extract_event_names_from_csv(csv_path):
    labels = []
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        fieldnames = reader.fieldnames or []
        # Determine which column to use
        if 'event_name' in fieldnames:
            key = 'event_name'
        elif len(fieldnames) > 0:
            key = fieldnames[-1]
            print(f"[WARN] 'event_name' not found in {csv_path.name}; using last column '{key}'.")
        else:
            # No header case — fallback
            f.seek(0)
            plain_reader = csv.reader(f)
            for row in plain_reader:
                if row:
                    labels.append(row[-1])
            return labels

        for row in reader:
            if not row:
                continue
            val = row.get(key)
            if val is None:
                val = list(row.values())[-1] if row else ''
            labels.append(val)
    return labels

# %%
# --- MAIN EXECUTION ---

csv_files = sorted(source_dir.glob("*.csv"))
if not csv_files:
    print(f"No CSV files found in {source_dir.resolve()}")
else:
    for csv_file in csv_files:
        labels = extract_event_names_from_csv(csv_file)
        arr = np.array(labels, dtype=str)

        # Construct destination .npy file path
        npy_name = csv_file.stem + "_labels.npy"
        npy_path = dest_dir / npy_name

        np.save(npy_path, arr)
        print(f"Saved {len(arr)} labels → {npy_path.name}")

    print("\n✅ All files processed successfully!")
# Out:
# Saved 1788 labels → 00000995-100507_segments_labels.npy
# Saved 1430 labels → 00001006-100507_segments_labels.npy
# Saved 1512 labels → 00001008-100507_segments_labels.npy
# Saved 1323 labels → 00001010-100507_segments_labels.npy
# Saved 2183 labels → 00001016-100507_segments_labels.npy
# Saved 1525 labels → 00001018-100507_segments_labels.npy
# Saved 1650 labels → 00001020-100507_segments_labels.npy
# Saved 2207 labels → 00001028-100507_segments_labels.npy
# Saved 1498 labels → 00001041-100507_segments_labels.npy
# Saved 1530 labels → 00001043-100507_segments_labels.npy
# Saved 1513 labels → 00001069-100507_segments_labels.npy
# Saved 1455 labels → 00001073-100507_segments_labels.npy
# Saved 2169 labels → 00001084-100507_segments_labels.npy
# Saved 1561 labels → 00001086-100507_segments_labels.npy
# Saved 1612 labels → 00001093-100507_segments_labels.npy
# Saved 1922 labels → 00001097-100507_segments_labels.npy
# Saved 1500 labels → 00001110-100507_segments_labels.npy
# Saved 1354 labels → 00001118-100507_segments_labels.npy
# Saved 1696 labels → 00001120-100507_segments_labels.npy
# Saved 1553 labels → 00001126-100507_segments_labels.npy
# Saved 1769 labels → 00001127-100507_segments_labels.npy
# Saved 1417 labels → 00001131-100507_segments_labels.npy
# Saved 1558 labels → 00001139-100507_segments_labels.npy
# Saved 1726 labels → 00001143-100507_segments_labels.npy
# Saved 2306 labels → 00001147-100507_segments_labels.npy
# Saved 1631 labels → 00001153-100507_segments_labels.npy
# Saved 1272 labels → 00001157-100507_segments_labels.npy
# Saved 1737 labels → 00001161-100507_segments_labels.npy
# Saved 1572 labels → 00001163-100507_segments_labels.npy
# Saved 1258 labels → 00001171-100507_segments_labels.npy
# Saved 1400 labels → 00001182-100507_segments_labels.npy
# Saved 1442 labels → 00001186-100507_segments_labels.npy
# Saved 1190 labels → 00001191-100507_segments_labels.npy
# Saved 1599 labels → 00001198-100507_segments_labels.npy
# Saved 1315 labels → 00001202-100507_segments_labels.npy
# Saved 1758 labels → 00001206-100507_segments_labels.npy
# Saved 1943 labels → 00001222-100507_segments_labels.npy
# Saved 1550 labels → 00001224-100507_segments_labels.npy
# Saved 1468 labels → 00001234-100507_segments_labels.npy
# Saved 1453 labels → 00001245-100507_segments_labels.npy
# Saved 1462 labels → 00001247-100507_segments_labels.npy
# Saved 1625 labels → 00001249-100507_segments_labels.npy
# Saved 2627 labels → 00001250-100507_segments_labels.npy
# Saved 1694 labels → 00001254-100507_segments_labels.npy
# Saved 1470 labels → 00001256-100507_segments_labels.npy
# Saved 1809 labels → 00001258-100507_segments_labels.npy
# Saved 1265 labels → 00001262-100507_segments_labels.npy
# Saved 1902 labels → 00001263-100507_segments_labels.npy
# Saved 1780 labels → 00001274-100507_segments_labels.npy
# Saved 1893 labels → 00001276-100507_segments_labels.npy
# Saved 1385 labels → 00001282-100507_segments_labels.npy
# Saved 1502 labels → 00001285-100507_segments_labels.npy
# Saved 2941 labels → 00001287-100507_segments_labels.npy
# Saved 1453 labels → 00001295-100507_segments_labels.npy
# Saved 1765 labels → 00001301-100507_segments_labels.npy
# Saved 1845 labels → 00001306-100507_segments_labels.npy
# Saved 1877 labels → 00001318-100507_segments_labels.npy
# Saved 1922 labels → 00001320-100507_segments_labels.npy
# Saved 1430 labels → 00001322-100507_segments_labels.npy
# Saved 1391 labels → 00001324-100507_segments_labels.npy
# Saved 1595 labels → 00001329-100507_segments_labels.npy
# Saved 1468 labels → 00001331-100507_segments_labels.npy
# Saved 2161 labels → 00001335-100507_segments_labels.npy
# Saved 1467 labels → 00001342-100507_segments_labels.npy
# Saved 1471 labels → 00001355-100507_segments_labels.npy
# Saved 1096 labels → 00001357-100507_segments_labels.npy
# Saved 1992 labels → 00001358-100507_segments_labels.npy
# Saved 1516 labels → 00001367-100507_segments_labels.npy
# Saved 2180 labels → 00001369-100507_segments_labels.npy
# Saved 1577 labels → 00001380-100507_segments_labels.npy
# Saved 2749 labels → 00001382-100507_segments_labels.npy
# Saved 1589 labels → 00001388-100507_segments_labels.npy
# Saved 1475 labels → 00001390-100507_segments_labels.npy
# Saved 2067 labels → 00001392-100507_segments_labels.npy
# Saved 1557 labels → 00001396-100507_segments_labels.npy
# Saved 1932 labels → 00001398-100507_segments_labels.npy
# Saved 1496 labels → 00001400-100507_segments_labels.npy
# Saved 1311 labels → 00001408-100507_segments_labels.npy
# Saved 2284 labels → 00001411-100507_segments_labels.npy
# Saved 1447 labels → 00001412-100507_segments_labels.npy
# Saved 1393 labels → 00001414-100507_segments_labels.npy
# Saved 1891 labels → 00001419-100507_segments_labels.npy
# Saved 1671 labels → 00001424-100507_segments_labels.npy
# Saved 1602 labels → 00001432-100507_segments_labels.npy
# Saved 1575 labels → 00001442-100507_segments_labels.npy
# Saved 1147 labels → 00001444-100507_segments_labels.npy
# Saved 1650 labels → 00001447-100507_segments_labels.npy
# Saved 1449 labels → 00001449-100507_segments_labels.npy
# Saved 1813 labels → 00001451-100507_segments_labels.npy
# Saved 1335 labels → 00001457-100507_segments_labels.npy
# Saved 1985 labels → 00001459-100507_segments_labels.npy
# Saved 1349 labels → 00001463-100507_segments_labels.npy
# Saved 1921 labels → 00001474-100507_segments_labels.npy
# Saved 1259 labels → 00001478-100507_segments_labels.npy
# Saved 1993 labels → 00001486-100507_segments_labels.npy
# Saved 2123 labels → 00001488-100507_segments_labels.npy
# Saved 2041 labels → 00001498-100507_segments_labels.npy
# Saved 2240 labels → 00001500-100507_segments_labels.npy
# Saved 2111 labels → 00001508-100507_segments_labels.npy
# Saved 1107 labels → 00001510-100507_segments_labels.npy
# Saved 2104 labels → 00001516-100507_segments_labels.npy
# Saved 1948 labels → 00001518-100507_segments_labels.npy
# Saved 2101 labels → 00001521-100507_segments_labels.npy
# Saved 1080 labels → 00001549-100507_segments_labels.npy
# Saved 1390 labels → 00001550-100507_segments_labels.npy
# Saved 2123 labels → 00001554-100507_segments_labels.npy
# Saved 2803 labels → 00001556-100507_segments_labels.npy
# Saved 2225 labels → 00001558-100507_segments_labels.npy
# Saved 2118 labels → 00001568-100507_segments_labels.npy
# Saved 1106 labels → 00001571-100507_segments_labels.npy
# Saved 1158 labels → 00001575-100507_segments_labels.npy
# Saved 1388 labels → 00001576-100507_segments_labels.npy
# Saved 2556 labels → 00001577-100507_segments_labels.npy
# Saved 2445 labels → 00001579-100507_segments_labels.npy
# Saved 2597 labels → 00001593-100507_segments_labels.npy
# Saved 2309 labels → 00001594-100507_segments_labels.npy
# Saved 2368 labels → 00001597-100507_segments_labels.npy
# Saved 1318 labels → 00001606-100507_segments_labels.npy
# Saved 2600 labels → 00001607-100507_segments_labels.npy
# Saved 2509 labels → 00001611-100507_segments_labels.npy
# Saved 2626 labels → 00001614-100507_segments_labels.npy
# Saved 2620 labels → 00001615-100507_segments_labels.npy
# Saved 2570 labels → 00001616-100507_segments_labels.npy
# Saved 2656 labels → 00001619-100507_segments_labels.npy
# Saved 2458 labels → 00001623-100507_segments_labels.npy
# Saved 2435 labels → 00001626-100507_segments_labels.npy
# Saved 2679 labels → 00001629-100507_segments_labels.npy
# Saved 1261 labels → 00001636-100507_segments_labels.npy
# Saved 1408 labels → 00001640-100507_segments_labels.npy
# Saved 1104 labels → 00001642-100507_segments_labels.npy
# Saved 1992 labels → 00001643-100507_segments_labels.npy
# Saved 2078 labels → 00001649-100507_segments_labels.npy
# Saved 2142 labels → 00001656-100507_segments_labels.npy
# Saved 2192 labels → 00001658-100507_segments_labels.npy
# Saved 1045 labels → 00001661-100507_segments_labels.npy
# Saved 1397 labels → 00001667-100507_segments_labels.npy
# Saved 1689 labels → 00001669-100507_segments_labels.npy
# Saved 1764 labels → 00001673-100507_segments_labels.npy
# Saved 1056 labels → 00001677-100507_segments_labels.npy
# Saved 1973 labels → 00001679-100507_segments_labels.npy
# Saved 1542 labels → 00001681-100507_segments_labels.npy
# Saved 2082 labels → 00001683-100507_segments_labels.npy
# Saved 2158 labels → 00001687-100507_segments_labels.npy
# Saved 2065 labels → 00001689-100507_segments_labels.npy
# Saved 1981 labels → 00001695-100507_segments_labels.npy
# Saved 2050 labels → 00001701-100507_segments_labels.npy
#
# ✅ All files processed successfully!

# %%
# test
test_var = np.load(dest_dir/'00001016-100507_segments_labels.npy')

# %%
test_var[1756]
# Out:
# 'Normal'

# %%
test_var.shape
# Out:
# (2183,)
